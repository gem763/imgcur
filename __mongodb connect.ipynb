# %%
import pymongo
import spacy
import decouple
import glob
import datetime
from PIL import Image
from IPython.display import display
from tqdm.notebook import tqdm
from pytrends.request import TrendReq
import tweepy

config = decouple.AutoConfig(' ')
nlp = spacy.load("en_core_web_lg")
pytrends = TrendReq(hl='en-US', tz=360)

# %%
gsearch = 'photo'
pytrends.build_payload([gsearch], timeframe='now 4-H')
qrys = pytrends.related_queries()[gsearch]['rising']['query'].values
trend = ' '.join([_q.replace(gsearch, '').replace('  ', ' ').strip() for _q in qrys])
trend
# Out:
# 'ratha yatra ratha yatra santoshi mata ki rath yatra good morning jagannath bhagwan ka rath yatra rath yatra 2022 rath yatra 2022 happy rath yatra happy rath yatra good morning jagannath jagannath akhilesh yadav akhilesh yadav joy jagannath happy rath yatra 2022 happy rath yatra 2022 rath yatra wishes sri jagannath rath yatra download happy rath yatra image jagannath bhagwan rath yatra image akhilesh yadav birthday'

# %%
trend = ' '.join(set(trend.split(' '))); trend
# Out:
# 'county download đây with rental cover girl eknath background sidhu edit happy birthday moose gần pregnant webcam name and shinde frame paper doctor best design gosselin alia jagannath resizer facebook orange tiệm ratha printer studio family ji toy hd compressor beautiful day bhatt yatra wala inkjet cake editor ramdevpir vip'

# %%
client = pymongo.MongoClient(config('MONGODB_URI'))
client.list_database_names()
db = client.Cluster0
db.list_collection_names()
# Out:
# ['test', 'pix']

# %%
colpix = db.pix
colpix.count_documents({})
# Out:
# 100

# %%
# cursor = colpix.find(
#     {'$text': {'$search': 'happy'}}, 
#     {'score': {'$meta': 'textScore'}}
# )

# cursor.sort([('score', {'$meta': 'textScore'})])

# %%
pixs = list(colpix.find({ 'feed_id': {'$exists': False}})); len(pixs)
# Out:
# 100

# %%
sims = []
for _p in tqdm(pixs):
    sims.append((_p['hash'], nlp(trend).similarity(nlp(_p['labels'] + ' ' + _p['colors']))))
    
sims = sorted(sims, key=lambda x: -x[1])
sims[:5]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [('e72190fb04445540835f332bc2650cba7cf9712ec40c55a7cedae70725f075e6',
#   0.6804734256797678),
#  ('d955511110943c206f7bc6b29d26280fb5cc543a784515750b21f269b8d149cd',
#   0.6698975805475698),
#  ('0b518176b2796c6dba2c3fb94170d58492b9bbb35df06a620e0624e63d1fcb01',
#   0.6640945071719002),
#  ('bf5aa34cd4a17dbfe0c9f1b77aef3a4a6160c150bf70d0e6651046ad3fd8319b',
#   0.6616967408041096),
#  ('30c62013340de2dafd96105d9020c0d5d5298058365cd4ad81e95099b1eb636a',
#   0.6558782786543282)]

# %%
for _fname, _ in sims[:5]:
    _path = glob.glob('imgs/archive/' + _fname + '.*')[0]
    _img = Image.open(_path)
    _img = _img.resize((200, 200))
    display(_img)
# Out:
# <PIL.Image.Image image mode=P size=200x200>
# <PIL.Image.Image image mode=RGB size=200x200>
# <PIL.Image.Image image mode=RGBA size=200x200>
# <PIL.Image.Image image mode=RGB size=200x200>
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
_hash = sims[0][0]
pix = colpix.find_one({ 'hash': _hash }); pix
# Out:
# {'_id': ObjectId('62b548d5c7b38aac0d7c8afa'),
#  'labels': 'cloud sky billboard rectangle tree pink font signage tints_and_shades magenta pole advertising poster sign cumulus banner',
#  'urls': [],
#  'colors': 'silver gray',
#  'hash': '4a14f1a7ffae60268ab7b0fb07f2b6176bed64e4aca3c0fe280962c1cdb437bf',
#  'created_at': datetime.datetime(2022, 6, 24, 5, 17, 9, 85000)}

# %%
url = pix['urls'][0]; url
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 url = pix['urls'][0]; url
#
# IndexError: list index out of range

# %%
pix_upload = glob.glob('imgs/archive/' + _hash + '.*')[0]; pix_upload
# Out:
# 'imgs/archive/e0dde30ee30bafe1d99f753ad9b1763e22d5c6a0031f5ae130b787c06bb1e7a2.jpg'

# %%
#status = 'crawled from ' + url; status

# %%
bearer_token = config('TWITTER_BEARER_TOKEN')
consumer_key = config('TWITTER_CONSUMER_KEY')
consumer_secret = config('TWITTER_CONSUMER_SECRET')
access_token = config('TWITTER_ACCESS_TOKEN')
access_token_secret = config('TWITTER_ACCESS_TOKEN_SECRET')

auth = tweepy.OAuth1UserHandler(consumer_key, consumer_secret, access_token, access_token_secret)
api = tweepy.API(auth)

# %%
media = api.media_upload(filename=pix_upload)
api.create_media_metadata(media.media_id_string, url)
status = api.update_status(status='', media_ids=[media.media_id_string]);

# %%
status.id
# Out:
# 1540977132155043841

# %%
colpix.update_one(
    { 'hash': _hash }, 
    { '$set': { 'feed_id': status.id }}
    # { '$set': { 'posted_at': datetime.datetime.utcnow() }}
)

# %%
_timeline = api.user_timeline(); _timeline
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fcf11f6e700>, _json={'created_at': 'Sun Jun 26 08:35:52 +0000 2022', 'id': 1540977132155043841, 'id_str': '1540977132155043841', 'text': 'https://t.co/RPnFTsMu9x', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1540977125377081345, 'id_str': '1540977125377081345', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'url': 'https://t.co/RPnFTsMu9x', 'display_url': 'pic.twitter.com/RPnFTsMu9x', 'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 624, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1540977125377081345, 'id_str': '1540977125377081345', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'url': 'https://t.co/RPnFTsMu9x', 'display_url': 'pic.twitter.com/RPnFTsMu9x', 'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 624, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]}, 'source': '<a href="https://moiber.com" rel="nofollow">piixur</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1539129437886857219, 'id_str': '1539129437886857219', 'name': 'piixur', 'screen_name': 'piixur', 'location': '', 'description': 'image curator', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Tue Jun 21 06:13:55 +0000 2022', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'zxx'}, created_at=datetime.datetime(2022, 6, 26, 8, 35, 52, tzinfo=datetime.timezone.utc), id=1540977132155043841, id_str='1540977132155043841', text='https://t.co/RPnFTsMu9x', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1540977125377081345, 'id_str': '1540977125377081345', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg', 'url': 'https://t.co/RPnFTsMu9x', 'display_url': 'pic.twitter.com/RPnFTsMu9x', 'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1', 'type': 'photo', ' ...

# %%
_timeline[0].__dict__
# Out:
# {'_api': <tweepy.api.API at 0x7fcf11f6e700>,
#  '_json': {'created_at': 'Sun Jun 26 08:35:52 +0000 2022',
#   'id': 1540977132155043841,
#   'id_str': '1540977132155043841',
#   'text': 'https://t.co/RPnFTsMu9x',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1540977125377081345,
#      'id_str': '1540977125377081345',
#      'indices': [0, 23],
#      'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#      'url': 'https://t.co/RPnFTsMu9x',
#      'display_url': 'pic.twitter.com/RPnFTsMu9x',
#      'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 624, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1540977125377081345,
#      'id_str': '1540977125377081345',
#      'indices': [0, 23],
#      'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#      'url': 'https://t.co/RPnFTsMu9x',
#      'display_url': 'pic.twitter.com/RPnFTsMu9x',
#      'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 624, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]},
#   'source': '<a href="https://moiber.com" rel="nofollow">piixur</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1539129437886857219,
#    'id_str': '1539129437886857219',
#    'name': 'piixur',
#    'screen_name': 'piixur',
#    'location': '',
#    'description': 'image curator',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 2,
#    'listed_count': 0,
#    'created_at': 'Tue Jun 21 06:13:55 +0000 2022',
#    'favourites_count': 1,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'zxx'},
#  'created_at': datetime.datetime(2022, 6, 26, 8, 35, 52, tzinfo=datetime.timezone.utc),
#  'id': 1540977132155043841,
#  'id_str': '1540977132155043841',
#  'text': 'https://t.co/RPnFTsMu9x',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 1540977125377081345,
#     'id_str': '1540977125377081345',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#     'url': 'https://t.co/RPnFTsMu9x',
#     'display_url': 'pic.twitter.com/RPnFTsMu9x',
#     'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1',
#     'type': 'photo',
#     'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 624, 'h': 680, 'resize': 'fit'},
#      'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1540977125377081345,
#     'id_str': '1540977125377081345',
#     'indices': [0, 23],
#     'media_url': 'http://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/FWKmh_UagAE9Dt2.jpg',
#     'url': 'https://t.co/RPnFTsMu9x',
#     'display_url': 'pic.twitter.com/RPnFTsMu9x',
#     'expanded_url': 'https://twitter.com/piixur/status/1540977132155043841/photo/1',
#     'type': 'photo',
#     'sizes': {'medium': {'w': 1102, 'h': 1200, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 624, 'h': 680, 'resize': 'fit'},
#      'large': {'w': 1280, 'h': 1394, 'resize': 'fit'}}}]},
#  'source': 'piixur',
#  'source_url': 'https://moiber.com',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'author': User(_api=<tweepy.api.API object at 0x7fcf11f6e700>, _json={'id': 1539129437886857219, 'id_str': '1539129437886857219', 'name': 'piixur', 'screen_name': 'piixur', 'location': '', 'description': 'image curator', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Tue Jun 21 06:13:55 +0000 2022', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1539129437886857219, id_str='1539129437886857219', name='piixur', screen_name='piixur', location='', description='image curator', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=1, friends_count=2, listed_count=0, created_at=datetime.datetime(2022, 6, 21, 6, 13, 55, tzinfo=datetime.timezone.utc), favourites_count=1, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]),
#  'user': User(_api=<tweepy.api.API object at 0x7fcf11f6e700>, _json={'id': 1539129437886857219, 'id_str': '1539129437886857219', 'name': 'piixur', 'screen_name': 'piixur', 'location': '', 'description': 'image curator', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 2, 'listed_count': 0, 'created_at': 'Tue Jun 21 06:13:55 +0000 2022', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, id=1539129437886857219, id_str='1539129437886857219', name='piixur', screen_name='piixur', location='', description='image curator', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=1, friends_count=2, listed_count=0, created_at=datetime.datetime(2022, 6, 21, 6, 13, 55, tzinfo=datetime.timezone.utc), favourites_count=1, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1539132003618004992/crkxfq37_normal.jpg', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none', withheld_in_countries=[]),
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'zxx'}
