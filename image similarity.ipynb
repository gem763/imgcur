# %%
import mahotas as mh
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

image = mh.imread('imgs/pins/500px.com -BEN-MOFFATeede8499287565a4c8967ae0fa7522d5.jpg')

plt.figure(figsize=(8,8))
plt.imshow(image)
plt.show()
